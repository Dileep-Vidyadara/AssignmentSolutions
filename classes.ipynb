# %% [markdown]
# 1. Read about how to define a class in python, have a member variable & functions for class
# 2. Constructor of class
# 3. Create an object for the class
# 4. Call the class method to modify the member variable
# 5. Create a class, Car. Have attributes like weight, max_speed, number_of_wheels, service_dates(List of datetime) and methods like get_max_speed(), update_max_speed(), add_service_date(), get_service_dates() and other methods for fetching and modifying attribute values.
# 6. Create multiple objects for this class with different values passed to the constructor.
# 7. Extending a base class
# 8. Override a method
# 9. Call an overwritten method and non overwritten method from the object of the extended class
# 10. Create a base class Vehicle. Extend the class and create a Car and Bus. create objects for these classes

# %% [markdown]
# 1.Read about how to define a class in python, have a member variable & functions for class <br>
# 2.Constructor of class <br>
# 3.Create an object for the class

# %%
class Employee:
    ''' Doc String goes here '''
    
    min_age = 21
    max_age = 30
    nationality = 'Indian'
    
    def __init__(self, name, base_pay):
        self.name = name
        self.base_pay = base_pay

    def get_pay(self):
        return self.base_pay

emp_001 = Employee(name = 'Mary', base_pay= 20000)

# %% [markdown]
# 5.Create a class, Car. Have attributes like weight, max_speed, number_of_wheels, service_dates(List of datetime) and methods like get_max_speed(), update_max_speed(), add_service_date(), get_service_dates() and other methods for fetching and modifying attribute values. <br> <br>
# 6.Create multiple objects for this class with different values passed to the constructor.

# %%
class car:
    ''' DocString goes Here'''
    
    #weight = 1500
    #max_speed = 160
    #number_of_wheels = 4
    #service_dates = ['22-04-2022', '23-04-2022', '24-04-2022', '25-04-2022']
    
    def __init__(self, weight, max_speed, number_of_wheels, service_dates, global_NCAP_rating ):
        self.weight = weight
        self.max_speed = max_speed
        self.number_of_wheels = number_of_wheels
        self.service_dates = service_dates
        self.global_NCAP_rating =  global_NCAP_rating
    
    def get_max_speed(self, m_speed):
        print(f'Maximum Speed of this car is: {m_speed}')
    
    def update_max_speed(self, u_speed):
        print(f'Updated Speed of this car is: {u_speed}')
        
    def add_service_date(self, a_s_date):
        print(f'Select the servicce date: {a_s_date}')
        
    def get_service_dates(self, g_s_date):
        print(f'Get the Service Dates: {g_s_date}')
        
mahindra_xuv300 = car(weight=1500, max_speed= 180, number_of_wheels=4, service_dates=['2022-04-22', '2022-04-23', '2022-04-24', '2022-04-25'], global_NCAP_rating= 5)

tata_altroz = car(weight= 1400, max_speed=140, number_of_wheels=4, service_dates= ['2022-04-22', '2022-04-23', '2022-04-24', '2022-04-25'], global_NCAP_rating= 5)

tata_nexon = car(weight= 1600, max_speed= 200, number_of_wheels= 4, service_dates= ['2022-04-22', '2022-04-23', '2022-04-24', '2022-04-25'], global_NCAP_rating= 5 )

# %% [markdown]
# 7.Extending a base class <br>
# 8.Override a method <br>
# 9.Call an overwritten method and non overwritten method from the object of the extended class

# %%
class Employee:
    def __init__(self, name, base_pay):
        self.name = name
        self.base_pay = base_pay

    def get_pay(self):
        return self.base_pay


class SalesEmployee(Employee):
    def __init__(self, name, base_pay, sales_incentive):
        self.name = name
        self.base_pay = base_pay
        self.sales_incentive = sales_incentive

    def get_pay(self):
        return self.base_pay + self.sales_incentive

john = SalesEmployee('John', 5000, 1500)
print(john.get_pay())

jane = Employee('Jane', 5000)
print(jane.get_pay())
# Out:
# 6500
# 5000

# %% [markdown]
# 10.Create a base class Vehicle. <br> Extend the class and create a Car and Bus. <br> Create objects for these classes

# %%
class Vehicle:
    wheels = 4
    steering = 1
    engine = True
    
    def __init(self, brand, cc , color, capacity):
        self.brand = brand
        self.cc = cc
        self.color = color
        self.capacity = capacity
        
    def car_starting_price(self):
        print('Car Price starts from 9,99,999')
        
    def bus_starting_price(self):
        print('Bus Price starts from 29,00,000')
        
obc = Vehicle()
        
    
class Car(Vehicle):
    pass

nissan = Car()
nissan.car_starting_price()

class Bus(Vehicle):
    pass

volvo = Bus()
volvo.bus_starting_price()
# Out:
# Car Price starts from 9,99,999
# Bus Price starts from 29,00,000

# %%
''' 
import datetime

today_date =  datetime.date.today()
start = datetime.datetime.strptime("22-04-2022", "%d-%m-%Y")
end = datetime.datetime.strptime("30-04-2022", "%d-%m-%Y")
date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]

for date in date_generated:
    lst_date = date.strftime("%d-%m-%Y")
    print (lst_date)
'''
# Out:
# Out[125]: ' \nimport datetime\n\ntoday_date =  datetime.date.today()\nstart = datetime.datetime.strptime("22-04-2022", "%d-%m-%Y")\nend = datetime.datetime.strptime("30-04-2022", "%d-%m-%Y")\ndate_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]\n\nfor date in date_generated:\n    lst_date = date.strftime("%d-%m-%Y")\n    print (lst_date)\n'
